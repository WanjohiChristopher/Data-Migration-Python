# %%
#for connection to sql server
import pyodbc

# %%
#checking the drivers
pyodbc.drivers()
# Out:
# ['ODBC Driver 17 for SQL Server']

# %%
#using connection string
conn=pyodbc.connect("Driver={ODBC Driver 17 for SQL Server};Server=localhost;Database=AdventureWorks2019;UID=SA;PWD=Chris;")

# %%
conn

# %%
# performing query
query="SELECT Name, CreditRating FROM Purchasing.Vendor WHERE CreditRating<3"

# %%
query
# Out:
# 'SELECT Name, CreditRating FROM Purchasing.Vendor WHERE CreditRating<3'

# %%
#creating cursor to work with in the database
cursor=conn.cursor();

# %%
#execute query
cursor.execute(query)

# %%
#storing the results in a variable
data=cursor.fetchall()

# %%
print(data[:5])
# Out:
# [('Australia Bike Retailer', 1), ('Allenson Cycles', 2), ('Advanced Bicycles', 1), ('Trikes, Inc.', 2), ('Morgan Bike Accessories', 1)]

# %%
#closing the connection
cursor.close()

# %% [markdown]
# ## Using Pymssql

# %%
import pymssql
from os import getenv

# %%
connection=pymssql.connect(host='localhost',user="SA",password="Chris",database="AdventureWorks2019")

# %%
# performing query
query="SELECT * FROM Purchasing.Vendor WHERE CreditRating<3"

# %%
cursor=connection.cursor()

# %%
#execute query
cursor.execute(query)

# %%
#fetching data
cursor.fetchall()
# Out:
# [(1492,
#   'AUSTRALI0001',
#   'Australia Bike Retailer',
#   1,
#   True,
#   True,
#   None,
#   datetime.datetime(2011, 12, 23, 0, 0)),
#  (1494,
#   'ALLENSON0001',
#   'Allenson Cycles',
#   2,
#   True,
#   True,
#   None,
#   datetime.datetime(2011, 4, 25, 0, 0)),
#  (1496,
#   'ADVANCED0001',
#   'Advanced Bicycles',
#   1,
#   True,
#   True,
#   None,
#   datetime.datetime(2011, 4, 25, 0, 0)),
#  (1498,
#   'TRIKES0001',
#   'Trikes, Inc.',
#   2,
#   True,
#   True,
#   None,
#   datetime.datetime(2012, 2, 3, 0, 0)),
#  (1500,
#   'MORGANB0001',
#   'Morgan Bike Accessories',
#   1,
#   True,
#   True,
#   None,
#   datetime.datetime(2012, 2, 2, 0, 0)),
#  (1502,
#   'CYCLING0001',
#   'Cycling Master',
#   1,
#   True,
#   True,
#   None,
#   datetime.datetime(2011, 12, 24, 0, 0)),
#  (1504,
#   'CHICAGO0002',
#   'Chicago Rent-All',
#   2,
#   True,
#   True,
#   None,
#   datetime.datetime(2011, 12, 24, 0, 0)),
#  (1506,
#   'GREENWOO0001',
# ...

# %%
#commiting
connection.commit()

# %%
print(cursor.fetchone())
# Out:
# None

# %%
c=cursor.execute('select Name from Purchasing.Vendor')

# %% [markdown]
# ### SQL ALCHEMY

# %%
import pyodbc#https://medium.com/@anushkamehra16/connecting-to-sql-database-using-sqlalchemy-in-python-2be2cf883f85
import sqlalchemy as sq
from sqlalchemy import create_engine
import pandas as pd

# %%
#!pip install psycopg2-binary
# Out:
# ...
#   Using cached psycopg2_binary-2.9.1-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.4 MB)
# ...

# %%
import pandas as pd #we use function to_sql()
import pydoc#to connect to mysql server
import os
import psycopg2
from sqlalchemy import create_engine#create connection objects
import re #to use regular expression
database_name = 'AdventureWorksDW2019'
mssqlserver_servername = 'laptopname' 
# Name of the SQL Server here. If you're working on your local machine, it's the name of your machine.

mssqlserver_uri = f"mssql+pyodbcdatabase_name = 'AdventureWorksDW2019'"
mssqlserver_servername = 'laptopname' # Name of the SQL Server here. If you're working on your local machine, it's the name of your machine.

mssqlserver_uri = f"mssql+pyodbc://{os.environ.get('SA')}:{os.environ.get('Chris')}@{mssqlserver_servername}/{database_name}?driver=ODBC Driver 17 for SQL Server"
mssqlserver_engine = create_engine(mssqlserver_uri)

postgres_uri = f"postgres+psycopg2://{os.environ.get('postgres')}:{os.environ.get('Christopher3698')}@localhost:5432/{'movedata'}"
postgres_engine = create_engine(postgres_uri)

# %%
from sqlalchemy import create_engine
import pandas as pd
Server='kreezy-Pro'
Database='AdventureWorks2019'
Driver='ODBC Driver 17 for SQL Server'
Username='SA'
Password='Chris'
Database_connection=f'mssql://{Username}:{Password}@{Server}/{Database}?driver={Driver}'

# %%
engine=create_engine(Database_connection)
connection=engine.connect()

# %%
data=pd.read_sql_query("select * FROM Purchasing.Vendor WHERE CreditRating<3",connection)

# %%
data.columns
# Out:
# Index(['BusinessEntityID', 'AccountNumber', 'Name', 'CreditRating',
#        'PreferredVendorStatus', 'ActiveFlag', 'PurchasingWebServiceURL',
#        'ModifiedDate'],
#       dtype='object')

# %%
data.head()
# Out:
#    BusinessEntityID AccountNumber                     Name  CreditRating  \
# 0              1492  AUSTRALI0001  Australia Bike Retailer             1
# 1              1494  ALLENSON0001          Allenson Cycles             2
# 2              1496  ADVANCED0001        Advanced Bicycles             1
# 3              1498    TRIKES0001             Trikes, Inc.             2
# 4              1500   MORGANB0001  Morgan Bike Accessories             1
#
#    PreferredVendorStatus  ActiveFlag PurchasingWebServiceURL ModifiedDate
# 0                   True        True                    None   2011-12-23
# 1                   True        True                    None   2011-04-25
# 2                   True        True                    None   2011-04-25
# 3                   True        True                    None   2012-02-03
# 4                   True        True                    None   2012-02-02

# %% [markdown]
# ### Using the Psycopg

# %%
import psycopg



# conn = psycopg2.connect("dbname=suppliers port=5432 user=postgres password=postgres")

conn = psycopg.connect(host="localhost", port = 5432, dbname="movedata", user="postgres", password="Chris")

# Create a cursor object
cur = conn.cursor()

# A sample query of all data from the "vendors" table in the "suppliers" database
cur.execute("""SELECT * FROM custdatademo""")
query_results = cur.fetchall()
print(query_results)

# Close the cursor and connection to so the server can allocate
# bandwidth to other requests
cur.close()
conn.close()
# Out:
# [(1, 'elijahk', 'elijahkungu100@gmail.com', 'Sep 10 2021 10:36AM'), (2, 'chris', 'chrisu100@gmail.com', 'Sep 10 2021 10:36AM')]

# %%
print(cur.fetchone())
# Out:
# None
